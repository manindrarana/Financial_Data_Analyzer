# %% [markdown]
# # 01 just finding whats in the duckdb file how many tables and so on

# %%
import duckdb
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

db_path = '../../database/financial_data.duckdb'

# %%
conn = duckdb.connect(db_path)

# %%
conn.execute("show tables").df()
# Out:
#                         name
# 0               bybit_crypto
# 1         clean_bybit_crypto
# 2         clean_yahoo_stocks
# 3                 dim_assets
# 4                   dim_date
# 5               dim_interval
# 6         fact_price_history
# 7    gold_feature_statistics
# 8   gold_financial_analytics
# 9           gold_ml_features
# 10              yahoo_stocks

# %%
conn.execute("describe gold_ml_features").df()
# Out:
#          column_name column_type null   key default extra
# 0       asset_symbol     VARCHAR  YES  None    None  None
# 1        asset_class     VARCHAR  YES  None    None  None
# 2           exchange     VARCHAR  YES  None    None  None
# 3           interval     VARCHAR  YES  None    None  None
# 4               date   TIMESTAMP  YES  None    None  None
# 5               open      DOUBLE  YES  None    None  None
# 6               high      DOUBLE  YES  None    None  None
# 7                low      DOUBLE  YES  None    None  None
# 8              close      DOUBLE  YES  None    None  None
# 9             volume      DOUBLE  YES  None    None  None
# 10  daily_volatility      DOUBLE  YES  None    None  None
# 11             sma_7      DOUBLE  YES  None    None  None
# 12            sma_30      DOUBLE  YES  None    None  None
# 13            rsi_14      DOUBLE  YES  None    None  None
# 14              macd      DOUBLE  YES  None    None  None
# 15       macd_signal      DOUBLE  YES  None    None  None
# 16    macd_histogram      DOUBLE  YES  None    None  None
# 17            roc_10      DOUBLE  YES  None    None  None
# 18            roc_20      DOUBLE  YES  None    None  None
# 19           stoch_k      DOUBLE  YES  None    None  None
# 20           stoch_d      DOUBLE  YES  None    None  None
# 21            ema_12      DOUBLE  YES  None    None  None
# 22            ema_26      DOUBLE  YES  None    None  None
# 23            ema_50      DOUBLE  YES  None    None  None
# 24           ema_200      DOUBLE  YES  None    None  None
# 25            sma_50      DOUBLE  YES  None    None  None
# 26           sma_100      DOUBLE  YES  None    None  None
# 27           sma_200      DOUBLE  YES  None    None  None
# 28          bb_upper      DOUBLE  YES  None    None  None
# 29         bb_middle      DOUBLE  YES  None    None  None
# 30          bb_lower      DOUBLE  YES  None    None  None
# 31          bb_width      DOUBLE  YES  None    None  None
# 32     bb_percentage      DOUBLE  YES  None    None  None
# 33            atr_14      DOUBLE  YES  None    None  None
# 34               obv      DOUBLE  YES  None    None  None
# 35              vwap      DOUBLE  YES  None    None  None
# 36     volume_sma_20      DOUBLE  YES  None    None  None
# 37      volume_ratio      DOUBLE  YES  None    None  None
# 38        returns_1d      DOUBLE  YES  None    None  None
# 39        returns_5d      DOUBLE  YES  None    None  None
# 40       returns_10d      DOUBLE  YES  None    None  None
# 41       returns_20d      DOUBLE  YES  None    None  None
# 42       log_returns      DOUBLE  YES  None    None  None
# 43          hl_ratio      DOUBLE  YES  None    None  None
# 44    close_position      DOUBLE  YES  None    None  None
# 45        prev_close      DOUBLE  YES  None    None  None
# 46       prev_volume      DOUBLE  YES  None    None  None
# 47         prev_high      DOUBLE  YES  None    None  None
# 48          prev_low      DOUBLE  YES  None    None  None

# %%
conn.execute("select asset_class, count(*) as total_rows,count(distinct asset_symbol) as unique_assets from gold_ml_features group by asset_class").df()
# Out:
#   asset_class  total_rows  unique_assets
# 0      Crypto      484598             11
# 1       Stock       43878              6
